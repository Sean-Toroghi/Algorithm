# %% [markdown]
# ### Matrix Multiplication
#
# ##### Method: Modified Divide and Conquer  (Strassen's Subcubic Matrix)

# %% [markdown]
# <br>
#
# Input: Two matrices A(nm) and B(mk)
#
# Output: Matrix C(nk) = A.B
#
#
# Steps:
#
#    1. divide A and B into 4 matrices (each) and compute __Seven__ products (recusrively)
#    2. add and subtract the pairs as following:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Run time: $O(N^2)$
#
# Implementation:  The matrx multiplication via two methods: Divide&Conquer $O(N^3)$, and modified Divide & Conquer (Strassen'ssubcubic Martix) $O(N^2)$  (Python v.3).
